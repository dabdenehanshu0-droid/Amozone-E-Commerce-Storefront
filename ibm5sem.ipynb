# %% [markdown]
# <a href="https://colab.research.google.com/github/dabdenehanshu0-droid/Amozone-E-Commerce-Storefront/blob/main/ibm5sem.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
